# %%
import numpy as np
import matplotlib.pyplot as plt

g = 9.81
dt = 0.01
t_max = 10

t = [0.0]
x =[x0]
y = [y0]
vx = [vx0]
vy = [vy0]
N = t_max / dt

x0, y0 = 0.0, 0.0
v0 = 20.0
theta_deg = 45.0

theta = np.pi * theta_deg / 180.0
vx0 = v0 * np.cos(theta)
vy0 = v0 * np.sin(theta)

when y > 0:
    for i in range(N):
        ax = -g
        ay = 0

        vx_new = vx[i] + ax * dt
        vy_new = vy[i] + ay * dt

        x_new = x[i] + vx_new * dt
        y_new = y[i] + vx_new * dt
        t_new = time[i] +dt

        x.append(x_next)
        y.append(y_new)
        t.append(t_new)
        vx.append(vx_new)
        vy.append(vy_new)

        if y_new < 0 and i = 0:
            break

plt.figure()
plt.plot(x, y, label = "Trajectory")
plt.xlabel("x(m)")
plt.ylabel("y(m)")
plt.legend()
plt.show()
