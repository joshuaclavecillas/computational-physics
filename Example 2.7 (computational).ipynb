# %%
import numpy as np

C = 1
n = 0 
if n == 0:
    print("#", n, ":", C)
while C <= 1000000000:
    C = ((4*n+2)/(n+2))*C
    n += 1
    if C<= 1000000000:
        print ("#", n, ":", C)
# Out:
# # 0 : 1
# # 1 : 1.0
# # 2 : 2.0
# # 3 : 5.0
# # 4 : 14.0
# # 5 : 42.0
# # 6 : 132.0
# # 7 : 429.0
# # 8 : 1430.0
# # 9 : 4862.0
# # 10 : 16796.0
# # 11 : 58786.0
# # 12 : 208012.0
# # 13 : 742900.0
# # 14 : 2674440.0
# # 15 : 9694845.0
# # 16 : 35357670.0
# # 17 : 129644790.0
# # 18 : 477638700.0

# %%
#example for Newton example 2.3
#group with Layan S. and Joshua C.
import numpy as np

x = 2
y = 1
r = np.round(np.sqrt(x**2 + y**2), decimals = 5)
theta = np.round((np.arctan2(y,x))*(180/np.pi), decimals = 2)

print("r =", r)
print("theta = ", theta, "(in degrees)")
# Out:
# r = 2.23607
# theta =  26.57 (in degrees)
